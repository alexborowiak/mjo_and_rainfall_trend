# %%
import load_dataset as load

# %%
rmm = load.load_rmm()

# %%
rmm
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 17189)
# Coordinates:
#   * time       (time) datetime64[ns] 1974-06-01 1974-06-02 ... 2021-06-22
# Data variables:
#     RMM1       (time) float64 1.634 1.603 1.516 1.51 ... -0.5787 -0.8269 -1.136
#     RMM2       (time) float64 1.203 1.015 1.086 1.036 ... -0.4567 -0.2899 -0.404
#     phase      (time) int64 5 5 5 5 5 6 6 6 6 7 6 5 ... 2 2 2 2 2 2 2 2 2 1 1 1
#     amplitude  (time) float64 2.029 1.897 1.865 1.831 ... 0.7372 0.8762 1.206

# %%
rmm.to_netcdf('/g/data/w40/ab2313/rmm.nc')

# %%
rmm.to_dataframe().to_csv('/g/data/w40/ab2313/rmm.csv')
